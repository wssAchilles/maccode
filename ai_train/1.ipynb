# %%
import torch
print(f"当前显卡: {torch.cuda.get_device_name(0)}")
a = torch.randn(10000, 10000, device='cuda')
# %time a @ a
# Out:
#   File "/tmp/ipykernel_1405/2123672717.py", line 1
#     import torch; print(f"当前显卡: {torch.cuda.get_device_name(0)}"); a = torch.randn(10000, 10000, device='cuda'); %time a @ a
#                                                                                                                  ^
# SyntaxError: invalid syntax
